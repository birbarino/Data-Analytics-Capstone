# %% [markdown]
# Hypothesis:
#
# APTs adjust TTPs in response to defensive measures and signs of detection.

# %%
import pandas as pd
import numpy as np
import os
import re
import chardet

def get_encoding(path):
    with open(path, 'rb') as f:
        raw = f.read(4096)  # read first 4KB

        # Use chardet to detect the encoding
        result = chardet.detect(raw)

        return result['encoding']

def get_files_recurse(path):
    result = []
    for root, dirs, files in os.walk(path):
        for file in files:
            full = os.path.join(root, file)
            result.append(full)
            
    return result

def load_all_csv(path, sep=',', recurse=False, verbose=False):
    files = [path + x for x in os.listdir(path)] if not recurse else get_files_recurse(path)
    d = dict()
    
    for f in files:
        if verbose:
            print(f)
        
        enc = get_encoding(f)
        d[f] = pd.read_csv(f, delimiter=sep, encoding=enc)
        
        # Modify df after each file is processed
    df = pd.concat(d.values(), ignore_index=True)
        
    return df

# %% [markdown]
# # Network Logs

# %% [markdown]
# ## Netflow

# %%
path = '../data/unraveled-apt/network-flows/'

# %%
df = load_all_csv(path, recurse=True, verbose=True)
# Out:
# ../data/unraveled-apt/network-flows/Week1_Day1-2_05262021-05272021/net1012x_Flow_labeled.csv
# ../data/unraveled-apt/network-flows/Week1_Day1-2_05262021-05272021/net1013x_Flow_labeled.csv
# /var/folders/58/dsswc9qs4gn_v8m37xx1fq4c0000gp/T/ipykernel_24854/2060571355.py:34: DtypeWarning: Columns (88) have mixed types. Specify dtype option on import or set low_memory=False.
#   d[f] = pd.read_csv(f, delimiter=sep, encoding=enc)
# ../data/unraveled-apt/network-flows/Week1_Day1-2_05262021-05272021/net1015x_Flow_labeled.csv
# ../data/unraveled-apt/network-flows/Week1_Day1-2_05262021-05272021/net1011x_Flow_labeled.csv
# ../data/unraveled-apt/network-flows/Week1_Day1-2_05262021-05272021/net1014x_Flow_labeled.csv
# ../data/unraveled-apt/network-flows/Week5_Day1_06212021/net1012x_Flow_labeled.csv
# ../data/unraveled-apt/network-flows/Week5_Day1_06212021/net1013x_Flow_labeled.csv
# ../data/unraveled-apt/network-flows/Week5_Day1_06212021/net1015x_Flow_labeled.csv
# ../data/unraveled-apt/network-flows/Week5_Day1_06212021/netgw_Flow_labeled.csv
# /var/folders/58/dsswc9qs4gn_v8m37xx1fq4c0000gp/T/ipykernel_24854/2060571355.py:34: DtypeWarning: Columns (88) have mixed types. Specify dtype option on import or set low_memory=False.
#   d[f] = pd.read_csv(f, delimiter=sep, encoding=enc)
# ../data/unraveled-apt/network-flows/Week5_Day1_06212021/net1011x_Flow_labeled.csv
# ../data/unraveled-apt/network-flows/Week5_Day1_06212021/net1014x_Flow_labeled.csv
# ../data/unraveled-apt/network-flows/Week6_Day6-7_07032021-07042021/net1012x_Flow_labeled.csv
# ../data/unraveled-apt/network-flows/Week6_Day6-7_07032021-07042021/net1013x_Flow_labeled.csv
# ../data/unraveled-apt/network-flows/Week6_Day6-7_07032021-07042021/net1015x_Flow_labeled.csv
# ../data/unraveled-apt/network-flows/Week6_Day6-7_07032021-07042021/netgw_Flow_labeled.csv
# ../data/unraveled-apt/network-flows/Week6_Day6-7_07032021-07042021/net1011x_Flow_labeled.csv
# ../data/unraveled-apt/network-flows/Week6_Day6-7_07032021-07042021/net1014x_Flow_labeled.csv
# ../data/unraveled-apt/network-flows/Week3_Day5-7_06112021-06132021/net1012x_Flow_labeled.csv
# ../data/unraveled-apt/network-flows/Week3_Day5-7_06112021-06132021/net1013x_Flow_labeled.csv
# ../data/unraveled-apt/network-flows/Week3_Day5-7_06112021-06132021/net1015x_Flow_labeled.csv
# ../data/unraveled-apt/network-flows/Week3_Day5-7_06112021-06132021/netgw_Flow_labeled.csv
# /var/folders/58/dsswc9qs4gn_v8m37xx1fq4c0000gp/T/ipykernel_24854/2060571355.py:34: DtypeWarning: Columns (88) have mixed types. Specify dtype option on import or set low_memory=False.
#   d[f] = pd.read_csv(f, delimiter=sep, encoding=enc)
# /var/folders/58/dsswc9qs4gn_v8m37xx1fq4c0000gp/T/ipykernel_24854/2060571355.py:34: DtypeWarning: Columns (88) have mixed types. Specify dtype option on import or set low_memory=False.
#   d[f] = pd.read_csv(f, delimiter=sep, encoding=enc)
# ../data/unraveled-apt/network-flows/Week3_Day5-7_06112021-06132021/net1011x_Flow_labeled.csv
# ../data/unraveled-apt/network-flows/Week3_Day5-7_06112021-06132021/net1014x_Flow_labeled.csv
# ../data/unraveled-apt/network-flows/Week4_Day3_7_06162021_06202021/net1012x_Flow_labeled.csv
# ../data/unraveled-apt/network-flows/Week4_Day3_7_06162021_06202021/net1013x_Flow_labeled.csv
# /var/folders/58/dsswc9qs4gn_v8m37xx1fq4c0000gp/T/ipykernel_24854/2060571355.py:34: DtypeWarning: Columns (88) have mixed types. Specify dtype option on import or set low_memory=False.
#   d[f] = pd.read_csv(f, delimiter=sep, encoding=enc)
# /var/folders/58/dsswc9qs4gn_v8m37xx1fq4c0000gp/T/ipykernel_24854/2060571355.py:34: DtypeWarning: Columns (88) have mixed types. Specify dtype option on import or set low_memory=False.
#   d[f] = pd.read_csv(f, delimiter=sep, encoding=enc)
# ../data/unraveled-apt/network-flows/Week4_Day3_7_06162021_06202021/net1015x_Flow_labeled.csv
# ../data/unraveled-apt/network-flows/Week4_Day3_7_06162021_06202021/netgw_Flow_labeled.csv
# ../data/unraveled-apt/network-flows/Week4_Day3_7_06162021_06202021/net1011x_Flow_labeled.csv
# ../data/unraveled-apt/network-flows/Week4_Day3_7_06162021_06202021/net1014x_Flow_labeled.csv
# ../data/unraveled-apt/network-flows/Week4_Day1_06152021/net1012x_Flow_labeled.csv
# ../data/unraveled-apt/network-flows/Week4_Day1_06152021/net1013x_Flow_labeled.csv
# /var/folders/58/dsswc9qs4gn_v8m37xx1fq4c0000gp/T/ipykernel_24854/2060571355.py:34: DtypeWarning: Columns (88) have mixed types. Specify dtype option on import or set low_memory=False.
#   d[f] = pd.read_csv(f, delimiter=sep, encoding=enc)
# ../data/unraveled-apt/network-flows/Week4_Day1_06152021/net1015x_Flow_labeled.csv
# ../data/unraveled-apt/network-flows/Week4_Day1_06152021/netgw_Flow_labeled.csv
# ../data/unraveled-apt/network-flows/Week4_Day1_06152021/net1011x_Flow_labeled.csv
# ../data/unraveled-apt/network-flows/Week4_Day1_06152021/net1014x_Flow_labeled.csv
# ../data/unraveled-apt/network-flows/Week3_Day1_06072021/net1012x_Flow_labeled.csv
# ../data/unraveled-apt/network-flows/Week3_Day1_06072021/net1013x_Flow_labeled.csv
# ../data/unraveled-apt/network-flows/Week3_Day1_06072021/net1015x_Flow_labeled.csv
# ../data/unraveled-apt/network-flows/Week3_Day1_06072021/netgw_Flow_labeled.csv
# ../data/unraveled-apt/network-flows/Week3_Day1_06072021/net1011x_Flow_labeled.csv
# ../data/unraveled-apt/network-flows/Week3_Day1_06072021/net1014x_Flow_labeled.csv
# ../data/unraveled-apt/network-flows/Week2_Day4_06032021/net1012x_Flow_labeled.csv
# ../data/unraveled-apt/network-flows/Week2_Day4_06032021/net1013x_Flow_labeled.csv
# ../data/unraveled-apt/network-flows/Week2_Day4_06032021/net1015x_Flow_labeled.csv
# ../data/unraveled-apt/network-flows/Week2_Day4_06032021/netgw_Flow_labeled.csv
# /var/folders/58/dsswc9qs4gn_v8m37xx1fq4c0000gp/T/ipykernel_24854/2060571355.py:34: DtypeWarning: Columns (88) have mixed types. Specify dtype option on import or set low_memory=False.
#   d[f] = pd.read_csv(f, delimiter=sep, encoding=enc)
# ../data/unraveled-apt/network-flows/Week2_Day4_06032021/net1011x_Flow_labeled.csv
# ../data/unraveled-apt/network-flows/Week2_Day4_06032021/net1014x_Flow_labeled.csv
# ../data/unraveled-apt/network-flows/Week1_Day3_05282021/net1012x_Flow_labeled.csv
# ../data/unraveled-apt/network-flows/Week1_Day3_05282021/net1013x_Flow_labeled.csv
# ../data/unraveled-apt/network-flows/Week1_Day3_05282021/net1015x_Flow_labeled.csv
# ../data/unraveled-apt/network-flows/Week1_Day3_05282021/net1011x_Flow_labeled.csv
# ../data/unraveled-apt/network-flows/Week1_Day3_05282021/net1014x_Flow_labeled.csv
# ../data/unraveled-apt/network-flows/Week6_Day2_06292021/net1012x_Flow_labeled.csv
# ../data/unraveled-apt/network-flows/Week6_Day2_06292021/net1013x_Flow_labeled.csv
# ../data/unraveled-apt/network-flows/Week6_Day2_06292021/net1015x_Flow_labeled.csv
# ../data/unraveled-apt/network-flows/Week6_Day2_06292021/netgw_Flow_labeled.csv
# ../data/unraveled-apt/network-flows/Week6_Day2_06292021/net1011x_Flow_labeled.csv
# ../data/unraveled-apt/network-flows/Week6_Day2_06292021/net1014x_Flow_labeled.csv
# ../data/unraveled-apt/network-flows/Week2_Day1_05312021/net1012x_Flow_labeled.csv
# ../data/unraveled-apt/network-flows/Week2_Day1_05312021/net1013x_Flow_labeled.csv
# ../data/unraveled-apt/network-flows/Week2_Day1_05312021/net1015x_Flow_labeled.csv
# ../data/unraveled-apt/network-flows/Week2_Day1_05312021/net1011x_Flow_labeled.csv
# ../data/unraveled-apt/network-flows/Week2_Day1_05312021/net1014x_Flow_labeled.csv
# ../data/unraveled-apt/network-flows/Week2_Day2_06012021/net1012x_Flow_labeled.csv
# ../data/unraveled-apt/network-flows/Week2_Day2_06012021/net1013x_Flow_labeled.csv
# ../data/unraveled-apt/network-flows/Week2_Day2_06012021/net1015x_Flow_labeled.csv
# ../data/unraveled-apt/network-flows/Week2_Day2_06012021/netgw_Flow_labeled.csv
# ../data/unraveled-apt/network-flows/Week2_Day2_06012021/net1011x_Flow_labeled.csv
# ../data/unraveled-apt/network-flows/Week2_Day2_06012021/net1014x_Flow_labeled.csv
# ../data/unraveled-apt/network-flows/Week5_Day6_06272021/net1012x_Flow_labeled.csv
# ../data/unraveled-apt/network-flows/Week5_Day6_06272021/net1013x_Flow_labeled.csv
# ../data/unraveled-apt/network-flows/Week5_Day6_06272021/net1015x_Flow_labeled.csv
# ../data/unraveled-apt/network-flows/Week5_Day6_06272021/netgw_Flow_labeled.csv
# ../data/unraveled-apt/network-flows/Week5_Day6_06272021/net1011x_Flow_labeled.csv
# ../data/unraveled-apt/network-flows/Week5_Day6_06272021/net1014x_Flow_labeled.csv
# ../data/unraveled-apt/network-flows/Week1_Day4_05292021/net1012x_Flow_labeled.csv
# ../data/unraveled-apt/network-flows/Week1_Day4_05292021/net1013x_Flow_labeled.csv
# ../data/unraveled-apt/network-flows/Week1_Day4_05292021/net1015x_Flow_labeled.csv
# ../data/unraveled-apt/network-flows/Week1_Day4_05292021/net1011x_Flow_labeled.csv
# ../data/unraveled-apt/network-flows/Week1_Day4_05292021/net1014x_Flow_labeled.csv
# /var/folders/58/dsswc9qs4gn_v8m37xx1fq4c0000gp/T/ipykernel_24854/2060571355.py:34: DtypeWarning: Columns (83,84) have mixed types. Specify dtype option on import or set low_memory=False.
#   d[f] = pd.read_csv(f, delimiter=sep, encoding=enc)
# ../data/unraveled-apt/network-flows/Week2_Day3_06022021/net1012x_Flow_labeled.csv
# /var/folders/58/dsswc9qs4gn_v8m37xx1fq4c0000gp/T/ipykernel_24854/2060571355.py:34: DtypeWarning: Columns (81,82,83,84) have mixed types. Specify dtype option on import or set low_memory=False.
#   d[f] = pd.read_csv(f, delimiter=sep, encoding=enc)
# ../data/unraveled-apt/network-flows/Week2_Day3_06022021/net1013x_Flow_labeled.csv
# /var/folders/58/dsswc9qs4gn_v8m37xx1fq4c0000gp/T/ipykernel_24854/2060571355.py:34: DtypeWarning: Columns (83,84) have mixed types. Specify dtype option on import or set low_memory=False.
#   d[f] = pd.read_csv(f, delimiter=sep, encoding=enc)
# ../data/unraveled-apt/network-flows/Week2_Day3_06022021/net1015x_Flow_labeled.csv
# ../data/unraveled-apt/network-flows/Week2_Day3_06022021/netgw_Flow_labeled.csv
# ../data/unraveled-apt/network-flows/Week2_Day3_06022021/net1011x_Flow_labeled.csv
# /var/folders/58/dsswc9qs4gn_v8m37xx1fq4c0000gp/T/ipykernel_24854/2060571355.py:34: DtypeWarning: Columns (81,82,83,84) have mixed types. Specify dtype option on import or set low_memory=False.
#   d[f] = pd.read_csv(f, delimiter=sep, encoding=enc)
# /var/folders/58/dsswc9qs4gn_v8m37xx1fq4c0000gp/T/ipykernel_24854/2060571355.py:34: DtypeWarning: Columns (81,82,83,84) have mixed types. Specify dtype option on import or set low_memory=False.
#   d[f] = pd.read_csv(f, delimiter=sep, encoding=enc)
# ../data/unraveled-apt/network-flows/Week2_Day3_06022021/net1014x_Flow_labeled.csv
# ../data/unraveled-apt/network-flows/Week3_Day2_06082021/net1012x_Flow_labeled.csv
# ../data/unraveled-apt/network-flows/Week3_Day2_06082021/net1013x_Flow_labeled.csv
# ../data/unraveled-apt/network-flows/Week3_Day2_06082021/net1015x_Flow_labeled.csv
# ../data/unraveled-apt/network-flows/Week3_Day2_06082021/netgw_Flow_labeled.csv
# /var/folders/58/dsswc9qs4gn_v8m37xx1fq4c0000gp/T/ipykernel_24854/2060571355.py:34: DtypeWarning: Columns (88) have mixed types. Specify dtype option on import or set low_memory=False.
#   d[f] = pd.read_csv(f, delimiter=sep, encoding=enc)
# ../data/unraveled-apt/network-flows/Week3_Day2_06082021/net1011x_Flow_labeled.csv
# ../data/unraveled-apt/network-flows/Week3_Day2_06082021/net1014x_Flow_labeled.csv
# ../data/unraveled-apt/network-flows/Week3_Day3_06092021/net1012x_Flow_labeled.csv
# ../data/unraveled-apt/network-flows/Week3_Day3_06092021/net1013x_Flow_labeled.csv
# ../data/unraveled-apt/network-flows/Week3_Day3_06092021/net1015x_Flow_labeled.csv
# ../data/unraveled-apt/network-flows/Week3_Day3_06092021/netgw_Flow_labeled.csv
# /var/folders/58/dsswc9qs4gn_v8m37xx1fq4c0000gp/T/ipykernel_24854/2060571355.py:34: DtypeWarning: Columns (88) have mixed types. Specify dtype option on import or set low_memory=False.
#   d[f] = pd.read_csv(f, delimiter=sep, encoding=enc)
# ../data/unraveled-apt/network-flows/Week3_Day3_06092021/net1011x_Flow_labeled.csv
# ../data/unraveled-apt/network-flows/Week3_Day3_06092021/net1014x_Flow_labeled.csv
# ../data/unraveled-apt/network-flows/Week6_Day5_07022021_part2/net1012x_Flow_labeled.csv
# ../data/unraveled-apt/network-flows/Week6_Day5_07022021_part2/net1013x_Flow_labeled.csv
# ../data/unraveled-apt/network-flows/Week6_Day5_07022021_part2/net1015x_Flow_labeled.csv
# ../data/unraveled-apt/network-flows/Week6_Day5_07022021_part2/netgw_Flow_labeled.csv
# /var/folders/58/dsswc9qs4gn_v8m37xx1fq4c0000gp/T/ipykernel_24854/2060571355.py:34: DtypeWarning: Columns (88) have mixed types. Specify dtype option on import or set low_memory=False.
#   d[f] = pd.read_csv(f, delimiter=sep, encoding=enc)
# ../data/unraveled-apt/network-flows/Week6_Day5_07022021_part2/net1011x_Flow_labeled.csv
# ../data/unraveled-apt/network-flows/Week6_Day5_07022021_part2/net1014x_Flow_labeled.csv
# ../data/unraveled-apt/network-flows/Week6_Day4_07012021/net1012x_Flow_labeled.csv
# ../data/unraveled-apt/network-flows/Week6_Day4_07012021/net1013x_Flow_labeled.csv
# ../data/unraveled-apt/network-flows/Week6_Day4_07012021/net1015x_Flow_labeled.csv
# ../data/unraveled-apt/network-flows/Week6_Day4_07012021/netgw_Flow_labeled.csv
# ../data/unraveled-apt/network-flows/Week6_Day4_07012021/net1011x_Flow_labeled.csv
# ../data/unraveled-apt/network-flows/Week6_Day4_07012021/net1014x_Flow_labeled.csv
# ../data/unraveled-apt/network-flows/Week2_Day5-7_06042021-06062021/net1012x_Flow_labeled.csv
# ../data/unraveled-apt/network-flows/Week2_Day5-7_06042021-06062021/net1013x_Flow_labeled.csv
# ../data/unraveled-apt/network-flows/Week2_Day5-7_06042021-06062021/net1015x_Flow_labeled.csv
# ../data/unraveled-apt/network-flows/Week2_Day5-7_06042021-06062021/netgw_Flow_labeled.csv
# /var/folders/58/dsswc9qs4gn_v8m37xx1fq4c0000gp/T/ipykernel_24854/2060571355.py:34: DtypeWarning: Columns (88) have mixed types. Specify dtype option on import or set low_memory=False.
#   d[f] = pd.read_csv(f, delimiter=sep, encoding=enc)
# ../data/unraveled-apt/network-flows/Week2_Day5-7_06042021-06062021/net1011x_Flow_labeled.csv
# ../data/unraveled-apt/network-flows/Week2_Day5-7_06042021-06062021/net1014x_Flow_labeled.csv
# ../data/unraveled-apt/network-flows/Week4_Day03_06162021/net1012x_Flow_labeled.csv
# ../data/unraveled-apt/network-flows/Week4_Day03_06162021/net1013x_Flow_labeled.csv
# ../data/unraveled-apt/network-flows/Week4_Day03_06162021/net1015x_Flow_labeled.csv
# /var/folders/58/dsswc9qs4gn_v8m37xx1fq4c0000gp/T/ipykernel_24854/2060571355.py:34: DtypeWarning: Columns (88) have mixed types. Specify dtype option on import or set low_memory=False.
#   d[f] = pd.read_csv(f, delimiter=sep, encoding=enc)
# ../data/unraveled-apt/network-flows/Week4_Day03_06162021/netgw_Flow_labeled.csv
# ../data/unraveled-apt/network-flows/Week4_Day03_06162021/net1011x_Flow_labeled.csv
# ../data/unraveled-apt/network-flows/Week4_Day03_06162021/net1014x_Flow_labeled.csv
# ../data/unraveled-apt/network-flows/Week4_Day2_06152021/net1011x_Week4_Day2_06152021_part_Flow_labeled.csv
# ../data/unraveled-apt/network-flows/Week4_Day2_06152021/net1012x_Flow_labeled.csv
# ../data/unraveled-apt/network-flows/Week4_Day2_06152021/net1013x_Flow_labeled.csv
# ../data/unraveled-apt/network-flows/Week4_Day2_06152021/net1013x_Week4_Day2_06152021_part_Flow_labeled.csv
# ../data/unraveled-apt/network-flows/Week4_Day2_06152021/net1015x_Flow_labeled.csv
# ../data/unraveled-apt/network-flows/Week4_Day2_06152021/netgw_Flow_labeled.csv
# /var/folders/58/dsswc9qs4gn_v8m37xx1fq4c0000gp/T/ipykernel_24854/2060571355.py:34: DtypeWarning: Columns (88) have mixed types. Specify dtype option on import or set low_memory=False.
#   d[f] = pd.read_csv(f, delimiter=sep, encoding=enc)
# ../data/unraveled-apt/network-flows/Week4_Day2_06152021/net1011x_Flow_labeled.csv
# ../data/unraveled-apt/network-flows/Week4_Day2_06152021/net1012x_Week4_Day2_06152021_part_Flow_labeled.csv
# ../data/unraveled-apt/network-flows/Week4_Day2_06152021/net1014x_Flow_labeled.csv
# ../data/unraveled-apt/network-flows/Week4_Day2_06152021/net1014x_Week4_Day2_06152021_part_Flow_labeled.csv
# ../data/unraveled-apt/network-flows/Week4_Day2_06152021/net1015x_Week4_Day2_06152021_part_Flow_labeled.csv
# ../data/unraveled-apt/network-flows/Week5_Day3_06232021/net1012x_Flow_labeled.csv
# ../data/unraveled-apt/network-flows/Week5_Day3_06232021/net1013x_Flow_labeled.csv
# ../data/unraveled-apt/network-flows/Week5_Day3_06232021/net1015x_Flow_labeled.csv
# ../data/unraveled-apt/network-flows/Week5_Day3_06232021/netgw_Flow_labeled.csv
# ../data/unraveled-apt/network-flows/Week5_Day3_06232021/net1011x_Flow_labeled.csv
# ../data/unraveled-apt/network-flows/Week5_Day3_06232021/net1014x_Flow_labeled.csv
# ../data/unraveled-apt/network-flows/Week5_Day2_06222021/net1012x_Flow_labeled.csv
# ../data/unraveled-apt/network-flows/Week5_Day2_06222021/net1013x_Flow_labeled.csv
# ../data/unraveled-apt/network-flows/Week5_Day2_06222021/net1015x_Flow_labeled.csv
# ../data/unraveled-apt/network-flows/Week5_Day2_06222021/netgw_Flow_labeled.csv
# ../data/unraveled-apt/network-flows/Week5_Day2_06222021/net1014x_Flow_labeled.csv
# ../data/unraveled-apt/network-flows/Week1_Day5_05302021/net1012x_Flow_labeled.csv
# ../data/unraveled-apt/network-flows/Week1_Day5_05302021/net1013x_Flow_labeled.csv
# ../data/unraveled-apt/network-flows/Week1_Day5_05302021/net1015x_Flow_labeled.csv
# ../data/unraveled-apt/network-flows/Week1_Day5_05302021/net1011x_Flow_labeled.csv
# ../data/unraveled-apt/network-flows/Week1_Day5_05302021/net1014x_Flow_labeled.csv
# ../data/unraveled-apt/network-flows/Week6_Day3_06302021/net1012x_Flow_labeled.csv
# ../data/unraveled-apt/network-flows/Week6_Day3_06302021/net1013x_Flow_labeled.csv
# ../data/unraveled-apt/network-flows/Week6_Day3_06302021/net1015x_Flow_labeled.csv
# ../data/unraveled-apt/network-flows/Week6_Day3_06302021/netgw_Flow_labeled.csv
# ../data/unraveled-apt/network-flows/Week6_Day3_06302021/net1011x_Flow_labeled.csv
# ../data/unraveled-apt/network-flows/Week6_Day3_06302021/net1014x_Flow_labeled.csv
# ../data/unraveled-apt/network-flows/Week5_Day5-6_06252021-06262021/net1012x_Flow_labeled.csv
# ../data/unraveled-apt/network-flows/Week5_Day5-6_06252021-06262021/net1013x_Flow_labeled.csv
# /var/folders/58/dsswc9qs4gn_v8m37xx1fq4c0000gp/T/ipykernel_24854/2060571355.py:34: DtypeWarning: Columns (88) have mixed types. Specify dtype option on import or set low_memory=False.
#   d[f] = pd.read_csv(f, delimiter=sep, encoding=enc)
# ../data/unraveled-apt/network-flows/Week5_Day5-6_06252021-06262021/net1015x_Flow_labeled.csv
# ../data/unraveled-apt/network-flows/Week5_Day5-6_06252021-06262021/netgw_Flow_labeled.csv
# ../data/unraveled-apt/network-flows/Week5_Day5-6_06252021-06262021/net1011x_Flow_labeled.csv
# ../data/unraveled-apt/network-flows/Week5_Day5-6_06252021-06262021/net1014x_Flow_labeled.csv
# ../data/unraveled-apt/network-flows/Week4_Day4_06172021/net1012x_Flow_labeled.csv
# ../data/unraveled-apt/network-flows/Week4_Day4_06172021/net1013x_Flow_labeled.csv
# ../data/unraveled-apt/network-flows/Week4_Day4_06172021/net1015x_Flow_labeled.csv
# /var/folders/58/dsswc9qs4gn_v8m37xx1fq4c0000gp/T/ipykernel_24854/2060571355.py:34: DtypeWarning: Columns (88) have mixed types. Specify dtype option on import or set low_memory=False.
#   d[f] = pd.read_csv(f, delimiter=sep, encoding=enc)
# ../data/unraveled-apt/network-flows/Week4_Day4_06172021/netgw_Flow_labeled.csv
# ../data/unraveled-apt/network-flows/Week4_Day4_06172021/net1011x_Flow_labeled.csv
# ../data/unraveled-apt/network-flows/Week4_Day4_06172021/net1014x_Flow_labeled.csv
# ../data/unraveled-apt/network-flows/Week6_Day5_07022021_part1/netgw_Flow_labeled.csv
# ../data/unraveled-apt/network-flows/Week5_Day4_06242021/net1013x_Flow_labeled.csv
# ../data/unraveled-apt/network-flows/Week5_Day4_06242021/net1015x_Flow_labeled.csv
# ../data/unraveled-apt/network-flows/Week5_Day4_06242021/netgw_Flow_labeled.csv
# ../data/unraveled-apt/network-flows/Week5_Day4_06242021/net1014x_Flow_labeled.csv
# ../data/unraveled-apt/network-flows/Week3_Day4_06102021/netgw_Flow_labeled.csv

# %%
dropme = [
    # Identifiers
    'fgid', 'id', ' id',
    
    # Redundant and unneeded Layer 2/3 info
    'src_oui', 'dst_oui', 'tunnel_id', 'ip_version',
    'vlan_id',
    
    # Sparse application metadata
    'requested_server_name', 'client_fingerprint', 
    'content_type', 'application_is_guessed',
    
    # Redundant bidirectional stats
    'bidirectional_min_ps', 'bidirectional_mean_ps', 
    'bidirectional_stddev_ps', 'bidirectional_max_ps',
    'bidirectional_min_piat_ms', 'bidirectional_mean_piat_ms',
    'bidirectional_stddev_piat_ms', 'bidirectional_max_piat_ms',
    
    # Redundant bidirectional TCP flags (keep directional)
    'bidirectional_syn_packets', 'bidirectional_cwr_packets',
    'bidirectional_ece_packets', 'bidirectional_urg_packets',
    'bidirectional_ack_packets', 'bidirectional_psh_packets',
    'bidirectional_rst_packets', 'bidirectional_fin_packets',
    
    # Potentially redundant timing
    'src2dst_last_seen_ms', 'dst2src_last_seen_ms'
]

reduced_df = df.drop(columns=dropme)

# %%
reduced_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6877157 entries, 0 to 6877156
# Data columns (total 61 columns):
#  #   Column                       Dtype
# ---  ------                       -----
#  0   expiration_id                int64
#  1   src_ip                       object
#  2   src_mac                      object
#  3   src_port                     int64
#  4   dst_ip                       object
#  5   dst_mac                      object
#  6   dst_port                     int64
#  7   protocol                     int64
#  8   bidirectional_first_seen_ms  int64
#  9   bidirectional_last_seen_ms   int64
#  10  bidirectional_duration_ms    int64
#  11  bidirectional_packets        int64
#  12  bidirectional_bytes          int64
#  13  src2dst_first_seen_ms        int64
#  14  src2dst_duration_ms          int64
#  15  src2dst_packets              int64
#  16  src2dst_bytes                int64
#  17  dst2src_first_seen_ms        int64
#  18  dst2src_duration_ms          int64
#  19  dst2src_packets              int64
#  20  dst2src_bytes                int64
#  21  src2dst_min_ps               int64
#  22  src2dst_mean_ps              float64
#  23  src2dst_stddev_ps            float64
#  24  src2dst_max_ps               int64
#  25  dst2src_min_ps               int64
#  26  dst2src_mean_ps              float64
#  27  dst2src_stddev_ps            float64
#  28  dst2src_max_ps               int64
#  29  src2dst_min_piat_ms          int64
#  30  src2dst_mean_piat_ms         float64
#  31  src2dst_stddev_piat_ms       float64
#  32  src2dst_max_piat_ms          int64
#  33  dst2src_min_piat_ms          int64
#  34  dst2src_mean_piat_ms         float64
#  35  dst2src_stddev_piat_ms       float64
#  36  dst2src_max_piat_ms          int64
#  37  src2dst_syn_packets          int64
#  38  src2dst_cwr_packets          int64
#  39  src2dst_ece_packets          int64
#  40  src2dst_urg_packets          int64
#  41  src2dst_ack_packets          int64
#  42  src2dst_psh_packets          int64
#  43  src2dst_rst_packets          int64
#  44  src2dst_fin_packets          int64
#  45  dst2src_syn_packets          int64
#  46  dst2src_cwr_packets          int64
#  47  dst2src_ece_packets          int64
#  48  dst2src_urg_packets          int64
#  49  dst2src_ack_packets          int64
#  50  dst2src_psh_packets          int64
#  51  dst2src_rst_packets          int64
#  52  dst2src_fin_packets          int64
#  53  application_name             object
#  54  application_category_name    object
#  55  server_fingerprint           object
#  56  user_agent                   object
#  57  Activity                     object
#  58  Stage                        object
#  59  DefenderResponse             object
#  60  Signature                    object
# dtypes: float64(8), int64(41), object(12)
# memory usage: 3.1+ GB

# %%
int_cols = reduced_df.dtypes[reduced_df.dtypes == 'int64'].index.tolist()
maxes = reduced_df[int_cols].max()

uint16 = maxes < 65536
uint16 = uint16[uint16].index.tolist()

uint32 = maxes < 4294967295  # includes uint16 cols, but we will do that type change after this one
uint32 = uint32[uint32].index.tolist()

float32 = reduced_df.dtypes[reduced_df.dtypes == 'float64'].index.tolist()

categories = [
    'src_ip', 'dst_ip', 'src_mac', 
    'dst_mac', 'expiration_id', 'application_name', 
    'user_agent', 'server_fingerprint', 'Activity', 
    'DefenderResponse', 'Signature', 'Stage',
    'application_category_name'
]

# %%
reduced_df[categories] = reduced_df[categories].astype('category')
reduced_df[float32] = reduced_df[float32].astype('float32')
reduced_df[uint32] = reduced_df[uint32].astype('uint32')
reduced_df[uint16] = reduced_df[uint16].astype('uint16')

# %%
import gc


# lets free up some memory
del df
gc.collect()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[207], line 1
# ----> 1 del df  # lets free up some memory
#       2 gc.collect()
#
# NameError: name 'df' is not defined

# %%
reduced_df['flow_start'] = pd.to_datetime(reduced_df['bidirectional_first_seen_ms'], unit='ms')
reduced_df['flow_end'] = pd.to_datetime(reduced_df['bidirectional_last_seen_ms'], unit='ms')

# %%
reduced_df.drop(columns=['flow_start', 'flow_end']).to_csv('../data/unraveled-apt/network-flows/reduced_nf.csv')

# %%
reduced_df = pd.read_csv('../data/unraveled-apt/network-flows/reduced_nf.csv')

# %% [markdown]
# # Linux Host Logs

# %% [markdown]
# ## `audit`

# %%
path = os.path.split(os.getcwd())[0] + '/data/unraveled-apt/host-logs/audit/'
audit_df = load_all_csv(path, sep=';')

# %%
audit_df.shape
# Out:
# (264320, 5)

# %% [markdown]
# On the last row, there appears to be some preceeding whitespace in the LogEvent column. Lets handle that:

# %%
for col in audit_df.columns:
    try:
        audit_df[col] = audit_df[col].str.strip()
    except:
        continue

# %% [markdown]
# We will need to reindex this DF since we combined a bunch of files, basically.

# %%
pat = re.compile(r"msg=('.*')")

# %%
msg_df = audit_df.LogEvent.str.extract(r"msg=('.*')")
no_msg = audit_df.LogEvent.str.replace(r"msg=('.*')", repl='', regex=True)

# %% [markdown]
# We are having to do some funky business to retain the `msg` field. If we were to split the output below on spaces or `=`, it would mangle the message and split it up in a less than ideal way for maintaining data integrity.

# %%
msg_df.iloc[5][0]
# Out:
# '\'op=PAM:session_close acct="root" exe="/usr/bin/sudo" hostname=? addr=? terminal=/dev/pts/5 res=success\''

# %% [markdown]
# Here is what the `no_msg` series looks like now. We can proceeed with converting this into a DataFrame.

# %%
print(no_msg.iloc[111])
print(audit_df.LogEvent.iloc[111])
# Out:
# type=USER_START ts=1621862701.432 tsid=600 pid=15765 uid=0 auid=0 ses=3575
# type=USER_START ts=1621862701.432 tsid=600 pid=15765 uid=0 auid=0 ses=3575 msg='op=PAM:session_open acct="root" exe="/usr/sbin/cron" hostname=? addr=? terminal=cron res=success'

# %%
logs = no_msg.str.split()

# %%
logs.iloc[logs.shape[0]-1]
# Out:
# ['type=USER_START',
#  'ts=1625992741.358',
#  'tsid=78499',
#  'pid=789481',
#  'uid=0',
#  'auid=1000',
#  'ses=5754',
#  'subj==unconfined',
#  'UID="root"',
#  'AUID="ubuntu"']

# %%
expand_logs = logs.apply(lambda x: {b[0]: b[1] for b in [a.split('=') for a in x]}).to_dict()
dict(list(expand_logs.items())[:2]) # logs are expanded to a dictionary of dictionaries
# Out:
# {0: {'type': 'DAEMON_START',
#   'ts': '1621837767.969',
#   'tsid': '9329',
#   'op': 'start',
#   'ver': '2.8.2',
#   'format': 'raw',
#   'kernel': '5.3.0-40-generic',
#   'auid': '4294967295',
#   'pid': '13687',
#   'uid': '0',
#   'ses': '4294967295',
#   'subj': 'unconfined',
#   'res': 'success'},
#  1: {'type': 'CONFIG_CHANGE',
#   'ts': '1621837767.983',
#   'tsid': '489',
#   'op': 'set',
#   'audit_backlog_limit': '8192',
#   'old': '64',
#   'auid': '4294967295',
#   'ses': '4294967295',
#   'res': '1'}}

# %%
log_df = pd.DataFrame(expand_logs).T
print(log_df.head(6))

del expand_logs
# Out:
#             type              ts  tsid     op    ver format            kernel  \
# 0   DAEMON_START  1621837767.969  9329  start  2.8.2    raw  5.3.0-40-generic
# 1  CONFIG_CHANGE  1621837767.983   489    set    NaN    NaN               NaN
# 2  CONFIG_CHANGE  1621837767.983   490    set    NaN    NaN               NaN
# 3  CONFIG_CHANGE  1621837767.983   491    set    NaN    NaN               NaN
# 4  SERVICE_START  1621837767.987   492    NaN    NaN    NaN               NaN
# 5       USER_END  1621837780.539   493    NaN    NaN    NaN               NaN
#
#          auid    pid  uid  ...  sig  dev prom old_prom AUID  UID OLD-AUID  \
# 0  4294967295  13687    0  ...  NaN  NaN  NaN      NaN  NaN  NaN      NaN
# 1  4294967295    NaN  NaN  ...  NaN  NaN  NaN      NaN  NaN  NaN      NaN
# 2  4294967295    NaN  NaN  ...  NaN  NaN  NaN      NaN  NaN  NaN      NaN
# 3  4294967295    NaN  NaN  ...  NaN  NaN  NaN      NaN  NaN  NaN      NaN
# 4  4294967295      1    0  ...  NaN  NaN  NaN      NaN  NaN  NaN      NaN
# 5        1000  13554    0  ...  NaN  NaN  NaN      NaN  NaN  NaN      NaN
#
#     ID  GID info
# 0  NaN  NaN  NaN
# 1  NaN  NaN  NaN
# 2  NaN  NaN  NaN
# 3  NaN  NaN  NaN
# 4  NaN  NaN  NaN
# 5  NaN  NaN  NaN
#
# [6 rows x 41 columns]

# %%
log_df.columns  # no msg column
# Out:
# Index(['type', 'ts', 'tsid', 'op', 'ver', 'format', 'kernel', 'auid', 'pid',
#        'uid', 'ses', 'subj', 'res', 'audit_backlog_limit', 'old',
#        'audit_failure', 'audit_backlog_wait_time', 'old-auid', 'tty',
#        'old-ses', 'apparmor', 'operation', 'profile', 'name', 'comm',
#        'requested_mask', 'denied_mask', 'fsuid', 'ouid', 'gid', 'exe', 'sig',
#        'dev', 'prom', 'old_prom', 'AUID', 'UID', 'OLD-AUID', 'ID', 'GID',
#        'info'],
#       dtype='object')

# %%
log_df['ts'] = pd.to_datetime(log_df['ts'].str.replace('.', ''), unit='ms')
log_df['ts'].head()
# Out:
# /var/folders/58/dsswc9qs4gn_v8m37xx1fq4c0000gp/T/ipykernel_32178/179783480.py:1: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   log_df['ts'] = pd.to_datetime(log_df['ts'].str.replace('.', ''), unit='ms')
# 0   2021-05-24 06:29:27.969
# 1   2021-05-24 06:29:27.983
# 2   2021-05-24 06:29:27.983
# 3   2021-05-24 06:29:27.983
# 4   2021-05-24 06:29:27.987
# Name: ts, dtype: datetime64[ns]

# %%
# Create DataFrame of labeled audit log data
labeled_audit_df = pd.concat([
        msg_df,  # contains the retained msg field
        log_df,  # contains the rest of the log, parsed
        audit_df[audit_df.columns[1:]]  # slice off first column, since we just expanded that.
    ], 
    axis=1)

labeled_audit_df.rename({0: 'msg'}, inplace=True, axis=1)

# %%
# reordering the columns to put the msg field in position 11
labeled_audit_df = labeled_audit_df[labeled_audit_df.columns[1:].insert(11, 'msg')]

# %%
labeled_audit_df.to_csv('../data/cleaned/audit.csv', index=False)

# %% [markdown]
# ## `auth`

# %%
path = os.path.split(os.getcwd())[0] + '/data/unraveled-apt/host-logs/auth/'
auth_df = load_all_csv(path, sep='|')

# %%
for col in auth_df.columns[1:]:
    print(auth_df[col].value_counts(), end=f'\n{'-'*20}\n')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 for col in auth_df.columns[1:]:
#       2     print(auth_df[col].value_counts(), end=f'\n{'-'*20}\n')
#
# NameError: name 'auth_df' is not defined

# %%
auth_df.LogEvent.iloc[[5, 10, 15, 20, 25, 100, 200, 300, 1000, 2000]].values
# Out:
# array(['Jun 13 00:15:01 kali CRON[328966]: pam_unix(cron:session): session closed for user root',
#        'Jun 13 00:35:01 kali CRON[329034]: pam_unix(cron:session): session opened for user root by (uid=0)',
#        'Jun 13 00:45:01 kali CRON[329086]: pam_unix(cron:session): session closed for user root',
#        'Jun 13 01:09:01 kali CRON[329103]: pam_unix(cron:session): session opened for user root by (uid=0)',
#        'Jun 13 01:17:01 kali CRON[329153]: pam_unix(cron:session): session closed for user root',
#        'Jun 13 05:17:01 kali CRON[329689]: pam_unix(cron:session): session opened for user root by (uid=0)',
#        'Jun 13 10:39:01 kali CRON[330494]: pam_unix(cron:session): session opened for user root by (uid=0)',
#        'Jun 13 16:15:01 kali CRON[331321]: pam_unix(cron:session): session opened for user root by (uid=0)',
#        "Jun 14 11:30:10 kali sshd[336289]: lastlog_openseek: Couldn't stat /var/log/lastlog: No such file or directory",
#        'Jun 15 23:09:01 kali CRON[390994]: pam_unix(cron:session): session closed for user root'],
#       dtype=object)

# %%
logs = auth_df.LogEvent.apply(lambda x: x.split(' ', maxsplit=5))
logs.head().values
# Out:
# array([list(['Jun', '13', '00:05:01', 'kali', 'CRON[328914]:', 'pam_unix(cron:session): session opened for user root by (uid=0)']),
#        list(['Jun', '13', '00:05:01', 'kali', 'CRON[328914]:', 'pam_unix(cron:session): session closed for user root']),
#        list(['Jun', '13', '00:09:01', 'kali', 'CRON[328918]:', 'pam_unix(cron:session): session opened for user root by (uid=0)']),
#        list(['Jun', '13', '00:09:01', 'kali', 'CRON[328918]:', 'pam_unix(cron:session): session closed for user root']),
#        list(['Jun', '13', '00:15:01', 'kali', 'CRON[328966]:', 'pam_unix(cron:session): session opened for user root by (uid=0)'])],
#       dtype=object)

# %%
df = pd.DataFrame(data=logs.tolist(), columns=['month', 'day', 'time', 'hostname', 'app', 'msg'])

# %%
df['ts'] = "2021-"+df['month']+"-"+df['day']+" "+df['time']
df['ts'] = pd.to_datetime(df['ts'])

# %%
# Drop redundant date cols and make ts col 0
df.drop(['month', 'day', 'time'], axis=1, inplace=True, errors='ignore')
df = df[df.columns[:-1].insert(0, 'ts')]

# %%
df.head()
# Out:
#                    ts hostname            app  \
# 0 2021-06-13 00:05:01     kali  CRON[328914]:
# 1 2021-06-13 00:05:01     kali  CRON[328914]:
# 2 2021-06-13 00:09:01     kali  CRON[328918]:
# 3 2021-06-13 00:09:01     kali  CRON[328918]:
# 4 2021-06-13 00:15:01     kali  CRON[328966]:
#
#                                                  msg
# 0  pam_unix(cron:session): session opened for use...
# 1  pam_unix(cron:session): session closed for use...
# 2  pam_unix(cron:session): session opened for use...
# 3  pam_unix(cron:session): session closed for use...
# 4  pam_unix(cron:session): session opened for use...

# %%
tmp = df['app'].str.split('[')

# %%
tmp = tmp.apply(lambda x: [e.strip(']:') for e in x])
tmp = tmp.apply(lambda x: x+[0] if len(x) == 1 else x)

# %%
tmp
# Out:
# 0        [CRON, 328914]
# 1        [CRON, 328914]
# 2        [CRON, 328918]
# 3        [CRON, 328918]
# 4        [CRON, 328966]
#               ...
# 89204         [sudo, 0]
# 89205         [sudo, 0]
# 89206         [sudo, 0]
# 89207         [sudo, 0]
# 89208         [sudo, 0]
# Name: app, Length: 89209, dtype: object

# %%
tmp = pd.DataFrame(tmp.tolist(), columns=['app','pid'])

# %%
tmp.head()
# Out:
#     app     pid
# 0  CRON  328914
# 1  CRON  328914
# 2  CRON  328918
# 3  CRON  328918
# 4  CRON  328966

# %%
df['app'] = tmp['app']
df['pid'] = tmp['pid']

# %%
df = df[['ts','hostname','app','pid','msg']]
df.head()
# Out:
#                    ts hostname   app     pid  \
# 0 2021-06-13 00:05:01     kali  CRON  328914
# 1 2021-06-13 00:05:01     kali  CRON  328914
# 2 2021-06-13 00:09:01     kali  CRON  328918
# 3 2021-06-13 00:09:01     kali  CRON  328918
# 4 2021-06-13 00:15:01     kali  CRON  328966
#
#                                                  msg
# 0  pam_unix(cron:session): session opened for use...
# 1  pam_unix(cron:session): session closed for use...
# 2  pam_unix(cron:session): session opened for use...
# 3  pam_unix(cron:session): session closed for use...
# 4  pam_unix(cron:session): session opened for use...

# %%
del tmp

# %%
df.msg = df.msg.apply(lambda x: x.strip())

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 89209 entries, 0 to 89208
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   ts        89209 non-null  datetime64[ns]
#  1   hostname  89209 non-null  category
#  2   app       89209 non-null  category
#  3   pid       89209 non-null  int64
#  4   msg       89209 non-null  object
# dtypes: category(2), datetime64[ns](1), int64(1), object(1)
# memory usage: 2.2+ MB

# %%
for col in ['hostname', 'app']:
    df[col] = df[col].astype('category')
    
df['pid'] = df['pid'].astype('int')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 89209 entries, 0 to 89208
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   ts        89209 non-null  datetime64[ns]
#  1   hostname  89209 non-null  category
#  2   app       89209 non-null  category
#  3   pid       89209 non-null  int64
#  4   msg       89209 non-null  object
# dtypes: category(2), datetime64[ns](1), int64(1), object(1)
# memory usage: 2.2+ MB

# %%
df.to_csv('../data/cleaned/auth.csv', index=False)

# %% [markdown]
# ## Combined

# %%
combined_linux_host_df = pd.concat([audit_df, auth_df], ignore_index=True)

# %%
combined_linux_host_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 353529 entries, 0 to 353528
# Data columns (total 5 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   LogEvent          353529 non-null  object
#  1   Activity          353529 non-null  object
#  2   Stage             353529 non-null  object
#  3   DefenderResponse  353529 non-null  object
#  4   Signature         74 non-null      object
# dtypes: object(5)
# memory usage: 13.5+ MB

# %% [markdown]
# -----

# %% [markdown]
# # Windows Host Logs

# %% [markdown]
# ## Security.evtx
